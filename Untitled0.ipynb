# %%
import pandas as pd

url = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"

df = pd.read_csv(url)

print(df.head())
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                   37.75                         0.5
# 1           NaN                   37.75                         0.5
# 2           NaN                   37.75                         0.5
# 3           NaN                   37.75                         0.5
# 4           NaN                   37.75                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                     0.51    41128772
# 1            64.83                     0.51    41128772
# 2            64.83                     0.51    41128772
# 3            64.83                     0.51    41128772
# 4            64.83                     0.51    41128772
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
pakistan = df[df['location'] == 'Pakistan']

pakistan.head()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 290973      PAK      Asia  Pakistan  2020-01-05          0.0        0.0
# 290974      PAK      Asia  Pakistan  2020-01-06          0.0        0.0
# 290975      PAK      Asia  Pakistan  2020-01-07          0.0        0.0
# 290976      PAK      Asia  Pakistan  2020-01-08          0.0        0.0
# 290977      PAK      Asia  Pakistan  2020-01-09          0.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 290973                 NaN           0.0         0.0                  NaN
# 290974                 NaN           0.0         0.0                  NaN
# 290975                 NaN           0.0         0.0                  NaN
# 290976                 NaN           0.0         0.0                  NaN
# 290977                 NaN           0.0         0.0                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 290973  ...          36.7                   59.61                         0.6
# 290974  ...          36.7                   59.61                         0.6
# 290975  ...          36.7                   59.61                         0.6
# 290976  ...          36.7                   59.61                         0.6
# 290977  ...          36.7                   59.61                         0.6
#
#         life_expectancy  human_development_index  population  \
# 290973            67.27                     0.56   235824864
# 290974            67.27                     0.56   235824864
# 290975            67.27                     0.56   235824864
# 290976            67.27                     0.56   235824864
# 290977            67.27                     0.56   235824864
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 290973                                   NaN                          NaN
# 290974                                   NaN                          NaN
# 290975                                   NaN                          NaN
# 290976                                   NaN                          NaN
# 290977                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 290973               NaN                                      NaN
# 290974               NaN                                      NaN
# 290975               NaN                                      NaN
# 290976               NaN                                      NaN
# 290977               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(pakistan['date'], pakistan['total_cases'])

plt.title("COVID-19 Total Cases in Pakistan")
plt.xlabel("Date")
plt.ylabel("Total Cases")

plt.xticks(rotation=45)

plt.show()

# %%
latest = pakistan.iloc[-1]

death_rate = (latest['total_deaths'] / latest['total_cases']) * 100

print("Death Rate:", round(death_rate, 2), "%")
# Out:
# Death Rate: 1.94 %

# %% [markdown]
# 1. COVID-19 cases in Pakistan increased rapidly during the pandemic waves.
#
# 2. Total cases showed a continuous upward trend over time.
#
# 3. The death rate remained relatively low compared to the total number of cases.
